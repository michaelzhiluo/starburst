# %%
import csv
import datetime
import json
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
LOGDIR = '../philly-traces/trace-data'
DATE_FORMAT_STR = '%Y-%m-%d %H:%M:%S'
MINUTES_PER_DAY = (24 * 60)
MICROSECONDS_PER_MINUTE = (60 * 1000)

# %%
def parse_date(date_str):
    """Parses a date string and returns a datetime object if possible.
    
       Args:
           date_str: A string representing a date.
        
       Returns:
           A datetime object if the input string could be successfully
           parsed, None otherwise.
    """
    if date_str is None or date_str == '' or date_str == 'None':
        return None
    return datetime.datetime.strptime(date_str, DATE_FORMAT_STR)

def timedelta_to_minutes(timedelta):
    """Converts a datetime timedelta object to minutes.
    
       Args:
           timedelta: The timedelta to convert.
           
       Returns:
           The number of minutes captured in the timedelta.
    """
    minutes = 0.0
    minutes += timedelta.days * MINUTES_PER_DAY
    minutes += timedelta.seconds / 60.0
    minutes += timedelta.microseconds / MICROSECONDS_PER_MINUTE
    return minutes

def round_to_nearest_minute(t):
    """Rounds a datetime object down to the nearest minute.
    
       Args:
           t: A datetime object.
           
        Returns:
            A new rounded down datetime object.
    """
    return t - datetime.timedelta(seconds=t.second, microseconds=t.microsecond)

def add_minute(t):
    """Adds a single minute to a datetime object.
    
       Args:
           t: A datetime object.
           
        Returns:
            A new datetime object with an additional minute.
    """
    return t + datetime.timedelta(seconds=60)

# %%
def get_cdf(data):
    """Returns the CDF of the given data.
    
       Args:
           data: A list of numerical values.
           
       Returns:
           An pair of lists (x, y) for plotting the CDF.
    """
    sorted_data = sorted(data)
    p = 100. * np.arange(len(sorted_data)) / (len(sorted_data) - 1)
    return sorted_data, p

# %%
class JobTrace:
    """Encapsulates a job."""
    
    def __init__(self, status, jobid, attempts, submitted_time, user):
        """Records job parameters and computes key metrics.
        
           Stores the passed in arguments as well as the number of GPUs
           requested by the job. In addition, computes the queueing delay
           as defined as the delta between the submission time and the start
           time of the first attempt. Finally, computes run time as defined
           as the delta between the initial attempt's start time and the last
           attempt's finish time.
           
           NOTE: Some jobs do not have any recorded attempts, and some attempts
           have missing start and/or end times. A job's latest attempt having no
           end time indicates that the job was still running when the log data
           was collected.
   
           Args:
               status: One of 'Pass', 'Killed', 'Failed'.
               jobid: The hash of the job id.
               attempts: A list of dicts, where each dict contains the following keys:
                   'start_time': The start time of the attempt.
                   'end_time': The end time of the attempt.
                   'detail': A list of nested dicts where each dict contains 
                             the following keys:
                        'ip': The server id.
                        'gpus': A list of the GPU ids allotted for this attempt.
                submitted_time: The time the job was submitted to the queue.
                user: The user's id.            
        """
        self._status = status
        self._jobid = jobid
        for attempt in attempts:
            attempt['start_time'] = parse_date(attempt['start_time'])
            attempt['end_time'] = parse_date(attempt['end_time'])
        self._attempts = attempts
        self._submitted_time = parse_date(submitted_time)
        self._user = user
        
        if len(self._attempts) == 0:
            self._num_gpus = None
            self._run_time = None
            self._queueing_delay = None
        else:
            self._num_gpus = sum([len(detail['gpus']) for detail in self._attempts[0]['detail']])
            if self._attempts[0]['start_time'] is None:
                self._run_time = None
                self._queueing_delay = None
            else:
                if self._attempts[-1]['end_time'] is None:
                    self._run_time = None
                else:
                    self._run_time = \
                        timedelta_to_minutes(self._attempts[-1]['end_time'] -
                                             self._attempts[0]['start_time'])
                self._queueing_delay = \
                    timedelta_to_minutes(self._attempts[0]['start_time'] -
                                         self._submitted_time)
    
    def __repr__(self):
        return (f'Job(job_id={self._jobid},\n'
                f'user={self._user},\n'
                f'status={self._status},\n'
                f'num_gpus = {self._num_gpus},\n'
                f'submitted_time = {self._submitted_time},\n'
                f'run_time={self._run_time}\n'
                f'attempts={self._attempts})')
    
    @property
    def status(self):
        return self._status
    
    @property
    def jobid(self):
        return self._jobid
    
    @property
    def attempts(self):
        return self._attempts
    
    @property
    def submitted_time(self):
        return self._submitted_time
    
    @property
    def user(self):
        return self._user
    
    @property
    def num_gpus(self):
        return self._num_gpus
    
    @property
    def queueing_delay(self):
        return self._queueing_delay
    
    @property
    def run_time(self):
        return self._run_time

# %%
def get_bucket_from_num_gpus(num_gpus):
    """Maps GPU count to a bucket for plotting purposes."""
    if num_gpus is None:
        return None
    if num_gpus == 1:
        return 0
    elif num_gpus >= 2 and num_gpus <= 4:
        return 1
    elif num_gpus >= 5 and num_gpus <= 8:
        return 2
    elif num_gpus > 8:
        return 3
    else:
        return None
    
def get_plot_config_from_bucket(bucket):
    """Returns plotting configuration information."""
    if bucket == 0:
        return ('1', 'green', '-')
    elif bucket == 1:
        return ('2-4', 'blue', '-.')
    elif bucket == 2:
        return ('5-8', 'red', '--')
    elif bucket == 3:
        return ('>8', 'purple', ':')

# %%
cluster_job_log_path = os.path.join(LOGDIR, 'cluster_job_log')
with open(cluster_job_log_path, 'r') as f:
    cluster_job_log = json.load(f)
jobs = [JobTrace(status=job['status'], jobid=job['jobid'], attempts=job['attempts'], submitted_time=job['submitted_time'], user=job['user']) for job in cluster_job_log]
jobs = sorted(jobs, key=lambda t: t._submitted_time)

# %%
print(jobs[0:1000])
# Out:
# [Job(job_id=application_1501012364013_9680,
# user=a547a3,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-07 10:03:01,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 12, 18, 15, 6), 'detail': [{'ip': 'm345', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 12, 18, 15, 16), 'end_time': datetime.datetime(2017, 9, 28, 20, 9, 19), 'detail': [{'ip': 'm180', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_12103,
# user=e90b30,
# status=Pass,
# num_gpus = 8,
# submitted_time = 2017-08-10 05:03:18,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 14, 22, 11, 27), 'detail': [{'ip': 'm192', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}]), Job(job_id=application_1501012364013_13756,
# user=ce36f0,
# status=Killed,
# num_gpus = None,
# submitted_time = 2017-08-11 19:13:46,
# run_time=None
# attempts=[]), Job(job_id=application_1501012364013_13883,
# user=e90b30,
# status=Failed,
# num_gpus = None,
# submitted_time = 2017-08-11 22:31:54,
# run_time=None
# attempts=[]), Job(job_id=application_1501012364013_13894,
# user=e90b30,
# status=Failed,
# num_gpus = 8,
# submitted_time = 2017-08-11 23:48:47,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 14, 22, 11, 27), 'detail': [{'ip': 'm272', 'gpus': ['gpu0', 'gpu1']}, {'ip': 'm78', 'gpus': ['gpu0', 'gpu1']}, {'ip': 'm119', 'gpus': ['gpu0', 'gpu1']}, {'ip': 'm198', 'gpus': ['gpu0', 'gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 14, 22, 48, 10), 'end_time': datetime.datetime(2017, 9, 15, 2, 48, 15), 'detail': [{'ip': 'm200', 'gpus': ['gpu0', 'gpu1']}, {'ip': 'm167', 'gpus': ['gpu0', 'gpu1']}, {'ip': 'm295', 'gpus': ['gpu0', 'gpu1']}, {'ip': 'm85', 'gpus': ['gpu0', 'gpu1']}]}]), Job(job_id=application_1501012364013_16024,
# user=a4559a,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-14 23:27:00,
# run_time=60217.21666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 2, 22, 10, 38), 'detail': [{'ip': 'm328', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 2, 22, 10, 43), 'end_time': datetime.datetime(2017, 9, 14, 23, 38, 7), 'detail': [{'ip': 'm50', 'gpus': ['gpu6']}]}, {'start_time': datetime.datetime(2017, 9, 14, 23, 38, 20), 'end_time': datetime.datetime(2017, 10, 13, 23, 22, 15), 'detail': [{'ip': 'm76', 'gpus': ['gpu1']}]}]), Job(job_id=application_1501012364013_19493,
# user=e90b30,
# status=Pass,
# num_gpus = 8,
# submitted_time = 2017-08-17 05:35:59,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 15, 2, 55, 17), 'detail': [{'ip': 'm9', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}]), Job(job_id=application_1501012364013_19495,
# user=e90b30,
# status=Failed,
# num_gpus = 8,
# submitted_time = 2017-08-17 05:38:11,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 13, 22, 58, 9), 'detail': [{'ip': 'm118', 'gpus': ['gpu0', 'gpu1']}, {'ip': 'm93', 'gpus': ['gpu0', 'gpu1']}, {'ip': 'm366', 'gpus': ['gpu0', 'gpu1']}, {'ip': 'm188', 'gpus': ['gpu0', 'gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 13, 22, 58, 49), 'end_time': datetime.datetime(2017, 9, 15, 2, 54, 36), 'detail': [{'ip': 'm128', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}]), Job(job_id=application_1501012364013_19529,
# user=a547a3,
# status=Failed,
# num_gpus = 1,
# submitted_time = 2017-08-17 07:50:40,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 9, 11, 19, 54), 'detail': [{'ip': 'm62', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 9, 11, 20, 9), 'end_time': datetime.datetime(2017, 9, 15, 0, 14, 46), 'detail': [{'ip': 'm156', 'gpus': ['gpu6']}]}, {'start_time': datetime.datetime(2017, 9, 15, 0, 14, 58), 'end_time': datetime.datetime(2017, 9, 24, 10, 56, 37), 'detail': [{'ip': 'm385', 'gpus': ['gpu3']}]}, {'start_time': datetime.datetime(2017, 9, 24, 10, 56, 50), 'end_time': datetime.datetime(2017, 9, 25, 20, 17, 8), 'detail': [{'ip': 'm31', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_19938,
# user=a547a3,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-18 01:29:43,
# run_time=53716.5
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 14, 11, 34, 51), 'detail': [{'ip': 'm326', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 14, 15, 3, 48), 'end_time': datetime.datetime(2017, 10, 4, 23, 6, 35), 'detail': [{'ip': 'm205', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 10, 4, 23, 15, 40), 'end_time': None, 'detail': [{'ip': 'm409', 'gpus': ['gpu2']}]}, {'start_time': datetime.datetime(2017, 10, 8, 9, 42, 49), 'end_time': None, 'detail': [{'ip': 'm35', 'gpus': ['gpu4']}]}, {'start_time': None, 'end_time': datetime.datetime(2017, 10, 9, 11, 1, 32), 'detail': [{'ip': 'm185', 'gpus': ['gpu7']}]}]), Job(job_id=application_1501012364013_19939,
# user=a547a3,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-18 01:29:44,
# run_time=64664.0
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 28, 7, 1, 35), 'detail': [{'ip': 'm103', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 28, 7, 1, 43), 'end_time': datetime.datetime(2017, 10, 17, 1, 29, 2), 'detail': [{'ip': 'm282', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_19940,
# user=a547a3,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-18 01:29:46,
# run_time=64663.86666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 14, 21, 32, 42), 'detail': [{'ip': 'm402', 'gpus': ['gpu2']}]}, {'start_time': datetime.datetime(2017, 9, 14, 22, 10, 8), 'end_time': datetime.datetime(2017, 10, 17, 1, 28, 54), 'detail': [{'ip': 'm226', 'gpus': ['gpu1']}]}]), Job(job_id=application_1501012364013_20139,
# user=a547a3,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-18 07:46:45,
# run_time=71838.25
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 28, 7, 1, 35), 'detail': [{'ip': 'm43', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 28, 7, 1, 43), 'end_time': datetime.datetime(2017, 10, 22, 1, 3, 17), 'detail': [{'ip': 'm104', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_20168,
# user=a547a3,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-18 08:01:30,
# run_time=71838.23333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 22, 1, 3, 16), 'detail': [{'ip': 'm332', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_20176,
# user=a547a3,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-18 08:31:36,
# run_time=71838.23333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 14, 5, 13, 25), 'detail': [{'ip': 'm248', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 14, 7, 4, 37), 'end_time': datetime.datetime(2017, 9, 14, 20, 17, 23), 'detail': [{'ip': 'm50', 'gpus': ['gpu4']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 22, 3), 'end_time': datetime.datetime(2017, 10, 22, 1, 3, 16), 'detail': [{'ip': 'm303', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_21310,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-18 21:20:18,
# run_time=47804.9
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 14, 22, 1, 27), 'detail': [{'ip': 'm269', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 14, 22, 1, 40), 'end_time': datetime.datetime(2017, 9, 14, 22, 48, 10), 'detail': [{'ip': 'm387', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 14, 22, 48, 16), 'end_time': datetime.datetime(2017, 10, 5, 8, 29, 56), 'detail': [{'ip': 'm387', 'gpus': ['gpu1']}]}]), Job(job_id=application_1501012364013_21984,
# user=0e4e56,
# status=Killed,
# num_gpus = 8,
# submitted_time = 2017-08-21 05:21:52,
# run_time=74548.93333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 20, 16, 32, 54), 'detail': [{'ip': 'm161', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 10, 20, 16, 48, 14), 'end_time': datetime.datetime(2017, 10, 23, 22, 13, 58), 'detail': [{'ip': 'm268', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}]), Job(job_id=application_1501012364013_22726,
# user=66999e,
# status=Killed,
# num_gpus = None,
# submitted_time = 2017-08-22 14:42:30,
# run_time=None
# attempts=[]), Job(job_id=application_1501012364013_23411,
# user=a547a3,
# status=Failed,
# num_gpus = 1,
# submitted_time = 2017-08-23 10:21:04,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 8, 0, 51, 24), 'detail': [{'ip': 'm103', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 8, 0, 51, 34), 'end_time': datetime.datetime(2017, 9, 17, 1, 35, 41), 'detail': [{'ip': 'm269', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 17, 1, 35, 55), 'end_time': datetime.datetime(2017, 9, 27, 20, 28, 42), 'detail': [{'ip': 'm302', 'gpus': ['gpu2']}]}]), Job(job_id=application_1501012364013_23412,
# user=a547a3,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-23 10:21:21,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 14, 22, 4, 49), 'detail': [{'ip': 'm303', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 14, 22, 4, 56), 'end_time': None, 'detail': [{'ip': 'm389', 'gpus': ['gpu1']}]}, {'start_time': None, 'end_time': datetime.datetime(2017, 10, 1, 19, 37, 11), 'detail': [{'ip': 'm271', 'gpus': ['gpu7']}]}]), Job(job_id=application_1501012364013_23793,
# user=1e93d0,
# status=Killed,
# num_gpus = 4,
# submitted_time = 2017-08-24 02:00:28,
# run_time=73320.9
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 23, 1, 45, 56), 'detail': [{'ip': 'm325', 'gpus': ['gpu0', 'gpu1', 'gpu3', 'gpu6']}]}]), Job(job_id=application_1501012364013_24154,
# user=c6a7f2,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-24 23:47:12,
# run_time=38719.53333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 29, 1, 4, 34), 'detail': [{'ip': 'm261', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_25011,
# user=ba97e6,
# status=Killed,
# num_gpus = None,
# submitted_time = 2017-08-26 09:45:07,
# run_time=None
# attempts=[]), Job(job_id=application_1501012364013_25315,
# user=0e4e56,
# status=Killed,
# num_gpus = 8,
# submitted_time = 2017-08-27 06:38:08,
# run_time=74548.88333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 3), 'end_time': datetime.datetime(2017, 9, 28, 23, 31, 29), 'detail': [{'ip': 'm56', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 28, 23, 31, 29), 'end_time': datetime.datetime(2017, 10, 23, 22, 13, 56), 'detail': [{'ip': 'm191', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}]), Job(job_id=application_1501012364013_26453,
# user=8151dc,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-29 05:07:27,
# run_time=80716.4
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 28, 5, 1, 26), 'detail': [{'ip': 'm414', 'gpus': ['gpu1']}]}]), Job(job_id=application_1501012364013_26537,
# user=0e9bd9,
# status=Failed,
# num_gpus = 1,
# submitted_time = 2017-08-29 08:57:20,
# run_time=67431.83333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 13, 12, 7, 5), 'detail': [{'ip': 'm1', 'gpus': ['gpu5']}]}, {'start_time': datetime.datetime(2017, 9, 13, 12, 7, 11), 'end_time': datetime.datetime(2017, 9, 13, 14, 4, 26), 'detail': [{'ip': 'm379', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 13, 14, 4, 32), 'end_time': datetime.datetime(2017, 9, 15, 0, 19, 7), 'detail': [{'ip': 'm102', 'gpus': ['gpu4']}]}, {'start_time': datetime.datetime(2017, 9, 15, 0, 19, 13), 'end_time': datetime.datetime(2017, 10, 10, 23, 6, 15), 'detail': [{'ip': 'm3', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 10, 10, 23, 6, 15), 'end_time': datetime.datetime(2017, 10, 18, 23, 36, 52), 'detail': [{'ip': 'm347', 'gpus': ['gpu7']}]}]), Job(job_id=application_1501012364013_26829,
# user=1e93d0,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-29 18:51:51,
# run_time=81542.28333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 28, 18, 47, 19), 'detail': [{'ip': 'm154', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_26860,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-29 20:01:41,
# run_time=47804.95
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 5, 8, 29, 59), 'detail': [{'ip': 'm255', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_27012,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-30 01:49:16,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 14, 18, 47, 38), 'detail': [{'ip': 'm46', 'gpus': ['gpu2']}]}, {'start_time': datetime.datetime(2017, 9, 14, 18, 49, 33), 'end_time': datetime.datetime(2017, 9, 14, 20, 50, 27), 'detail': [{'ip': 'm265', 'gpus': ['gpu3']}]}]), Job(job_id=application_1501012364013_27014,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-30 01:49:20,
# run_time=45896.75
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 14, 22, 48, 10), 'detail': [{'ip': 'm409', 'gpus': ['gpu3']}]}, {'start_time': datetime.datetime(2017, 9, 14, 22, 50, 21), 'end_time': datetime.datetime(2017, 9, 15, 2, 58, 6), 'detail': [{'ip': 'm226', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 8, 22), 'end_time': datetime.datetime(2017, 10, 4, 0, 41, 47), 'detail': [{'ip': 'm365', 'gpus': ['gpu0']}]}]), Job(job_id=application_1501012364013_27017,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-30 01:49:32,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 14, 18, 47, 45), 'detail': [{'ip': 'm265', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 14, 20, 16, 48), 'end_time': datetime.datetime(2017, 9, 14, 20, 50, 27), 'detail': [{'ip': 'm265', 'gpus': ['gpu4']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 29, 13), 'end_time': datetime.datetime(2017, 9, 17, 3, 38, 29), 'detail': [{'ip': 'm10', 'gpus': ['gpu1']}]}]), Job(job_id=application_1501012364013_27386,
# user=a4559a,
# status=Failed,
# num_gpus = 1,
# submitted_time = 2017-08-30 17:50:12,
# run_time=76112.5
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 24, 4, 9, 4), 'detail': [{'ip': 'm282', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 10, 24, 4, 9, 12), 'end_time': datetime.datetime(2017, 10, 24, 10, 9, 50), 'detail': [{'ip': 'm406', 'gpus': ['gpu7']}]}, {'start_time': datetime.datetime(2017, 10, 24, 10, 9, 57), 'end_time': datetime.datetime(2017, 10, 25, 0, 1, 33), 'detail': [{'ip': 'm44', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 10, 25, 0, 1, 48), 'end_time': datetime.datetime(2017, 10, 25, 0, 10, 4), 'detail': [{'ip': 'm202', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 10, 25, 0, 13, 4), 'end_time': datetime.datetime(2017, 10, 25, 0, 17, 32), 'detail': [{'ip': 'm202', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_0129,
# user=1e93d0,
# status=Killed,
# num_gpus = None,
# submitted_time = 2017-08-31 05:48:35,
# run_time=None
# attempts=[]), Job(job_id=application_1504131676014_0362,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-08-31 10:47:23,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 15, 3, 0, 42), 'detail': [{'ip': 'm237', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 8, 7), 'end_time': None, 'detail': [{'ip': 'm385', 'gpus': ['gpu5']}]}]), Job(job_id=application_1504131676014_0515,
# user=1e93d0,
# status=Killed,
# num_gpus = 4,
# submitted_time = 2017-08-31 19:00:57,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 14, 5, 13, 25), 'detail': [{'ip': 'm265', 'gpus': ['gpu1', 'gpu2', 'gpu3', 'gpu6']}]}, {'start_time': datetime.datetime(2017, 9, 14, 5, 13, 46), 'end_time': datetime.datetime(2017, 9, 14, 20, 17, 15), 'detail': [{'ip': 'm156', 'gpus': ['gpu0', 'gpu3', 'gpu5', 'gpu7']}]}]), Job(job_id=application_1504131676014_0517,
# user=1e93d0,
# status=Killed,
# num_gpus = 2,
# submitted_time = 2017-08-31 19:01:14,
# run_time=84420.5
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 30, 18, 45, 32), 'detail': [{'ip': 'm286', 'gpus': ['gpu0', 'gpu1']}]}]), Job(job_id=application_1504131676014_0557,
# user=a4559a,
# status=Failed,
# num_gpus = 1,
# submitted_time = 2017-08-31 21:46:48,
# run_time=None
# attempts=[{'start_time': None, 'end_time': datetime.datetime(2017, 9, 6, 10, 8), 'detail': [{'ip': 'm60', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 6, 10, 8, 5), 'end_time': datetime.datetime(2017, 9, 10, 15, 18, 48), 'detail': [{'ip': 'm372', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 10, 15, 18, 58), 'end_time': datetime.datetime(2017, 9, 14, 19, 27, 24), 'detail': [{'ip': 'm261', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_0793,
# user=ba97e6,
# status=Killed,
# num_gpus = 4,
# submitted_time = 2017-09-01 04:35:00,
# run_time=84987.93333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 31, 4, 12, 58), 'detail': [{'ip': 'm271', 'gpus': ['gpu0', 'gpu1', 'gpu5', 'gpu6']}]}]), Job(job_id=application_1504131676014_0836,
# user=ba97e6,
# status=Killed,
# num_gpus = 4,
# submitted_time = 2017-09-01 06:41:05,
# run_time=78648.43333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 9, 14, 18, 51, 50), 'detail': [{'ip': 'm171', 'gpus': ['gpu2', 'gpu3', 'gpu5', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 28, 12), 'end_time': datetime.datetime(2017, 9, 14, 21, 37, 50), 'detail': [{'ip': 'm256', 'gpus': ['gpu0', 'gpu1', 'gpu4', 'gpu6']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 59, 48), 'end_time': datetime.datetime(2017, 10, 26, 18, 33, 28), 'detail': [{'ip': 'm117', 'gpus': ['gpu2', 'gpu3', 'gpu5', 'gpu6']}]}]), Job(job_id=application_1504131676014_1103,
# user=1e93d0,
# status=Killed,
# num_gpus = 2,
# submitted_time = 2017-09-01 18:26:32,
# run_time=85835.76666666666
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 4, 4, 1, 55), 'detail': [{'ip': 'm8', 'gpus': ['gpu2', 'gpu3']}]}, {'start_time': datetime.datetime(2017, 10, 4, 4, 1, 55), 'end_time': datetime.datetime(2017, 10, 31, 18, 20, 48), 'detail': [{'ip': 'm366', 'gpus': ['gpu0', 'gpu1']}]}]), Job(job_id=application_1504131676014_1104,
# user=1e93d0,
# status=Killed,
# num_gpus = 4,
# submitted_time = 2017-09-01 18:27:43,
# run_time=85835.26666666666
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 31, 18, 20, 18), 'detail': [{'ip': 'm115', 'gpus': ['gpu0', 'gpu1', 'gpu3', 'gpu4']}]}]), Job(job_id=application_1504131676014_1222,
# user=bd2989,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-02 00:46:08,
# run_time=86060.7
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 3, 45, 2), 'end_time': datetime.datetime(2017, 10, 31, 22, 5, 44), 'detail': [{'ip': 'm345', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_1370,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-02 07:12:13,
# run_time=45689.26666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 7, 12, 25), 'end_time': datetime.datetime(2017, 9, 15, 3, 3, 1), 'detail': [{'ip': 'm370', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 15, 53), 'end_time': datetime.datetime(2017, 10, 4, 0, 41, 41), 'detail': [{'ip': 'm5', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_1395,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-02 07:15:55,
# run_time=45685.316666666666
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 7, 16, 10), 'end_time': datetime.datetime(2017, 9, 15, 3, 6, 59), 'detail': [{'ip': 'm189', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 13, 2), 'end_time': datetime.datetime(2017, 10, 4, 0, 41, 29), 'detail': [{'ip': 'm270', 'gpus': ['gpu4']}]}]), Job(job_id=application_1504131676014_1397,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-02 07:16:06,
# run_time=45685.316666666666
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 7, 16, 15), 'end_time': datetime.datetime(2017, 9, 15, 2, 53, 18), 'detail': [{'ip': 'm44', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 15, 2, 53, 30), 'end_time': datetime.datetime(2017, 10, 4, 0, 41, 34), 'detail': [{'ip': 'm391', 'gpus': ['gpu6']}]}]), Job(job_id=application_1504131676014_1404,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-02 07:16:44,
# run_time=45684.9
# attempts=[{'start_time': datetime.datetime(2017, 9, 2, 7, 16, 55), 'end_time': datetime.datetime(2017, 9, 15, 2, 57, 17), 'detail': [{'ip': 'm8', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 1, 30), 'end_time': datetime.datetime(2017, 10, 4, 0, 41, 49), 'detail': [{'ip': 'm332', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_2141,
# user=a03d7f,
# status=Pass,
# num_gpus = 8,
# submitted_time = 2017-09-04 10:30:41,
# run_time=37337.066666666666
# attempts=[{'start_time': datetime.datetime(2017, 9, 4, 10, 30, 53), 'end_time': datetime.datetime(2017, 9, 4, 10, 42, 44), 'detail': [{'ip': 'm305', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 4, 10, 42, 54), 'end_time': datetime.datetime(2017, 9, 4, 10, 49, 29), 'detail': [{'ip': 'm349', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 4, 10, 49, 39), 'end_time': datetime.datetime(2017, 9, 4, 11, 3, 54), 'detail': [{'ip': 'm305', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 4, 11, 4, 4), 'end_time': datetime.datetime(2017, 9, 30, 8, 47, 57), 'detail': [{'ip': 'm67', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}]), Job(job_id=application_1504131676014_2426,
# user=9b5f16,
# status=Killed,
# num_gpus = 8,
# submitted_time = 2017-09-05 06:20:03,
# run_time=74188.5
# attempts=[{'start_time': datetime.datetime(2017, 9, 5, 6, 20, 13), 'end_time': None, 'detail': [{'ip': 'm87', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 14, 4, 24, 15), 'end_time': datetime.datetime(2017, 10, 26, 18, 48, 43), 'detail': [{'ip': 'm30', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}]), Job(job_id=application_1504131676014_2739,
# user=bd2989,
# status=Failed,
# num_gpus = 1,
# submitted_time = 2017-09-05 22:20:26,
# run_time=82440.95
# attempts=[{'start_time': datetime.datetime(2017, 9, 5, 22, 22, 38), 'end_time': datetime.datetime(2017, 9, 14, 21, 1, 29), 'detail': [{'ip': 'm108', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 1, 43), 'end_time': datetime.datetime(2017, 9, 14, 21, 54, 48), 'detail': [{'ip': 'm409', 'gpus': ['gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 55), 'end_time': datetime.datetime(2017, 9, 20, 1, 5, 56), 'detail': [{'ip': 'm34', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 20, 1, 6, 3), 'end_time': datetime.datetime(2017, 11, 2, 4, 23, 35), 'detail': [{'ip': 'm31', 'gpus': ['gpu3']}]}]), Job(job_id=application_1504131676014_3232,
# user=9b5f16,
# status=Pass,
# num_gpus = 8,
# submitted_time = 2017-09-06 16:44:01,
# run_time=48606.61666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 6, 17, 10, 40), 'end_time': datetime.datetime(2017, 9, 6, 17, 18, 10), 'detail': [{'ip': 'm194', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 6, 17, 22, 30), 'end_time': None, 'detail': [{'ip': 'm30', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 14, 8, 13, 49), 'end_time': datetime.datetime(2017, 9, 28, 4, 21, 35), 'detail': [{'ip': 'm16', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 28, 4, 27, 44), 'end_time': datetime.datetime(2017, 10, 10, 11, 17, 17), 'detail': [{'ip': 'm162', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}]), Job(job_id=application_1504131676014_3286,
# user=9b5f16,
# status=Failed,
# num_gpus = 8,
# submitted_time = 2017-09-06 19:04:30,
# run_time=62257.1
# attempts=[{'start_time': datetime.datetime(2017, 9, 6, 19, 6, 47), 'end_time': datetime.datetime(2017, 9, 6, 19, 13, 2), 'detail': [{'ip': 'm47', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 6, 19, 23, 7), 'end_time': None, 'detail': [{'ip': 'm221', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 14, 7, 38, 42), 'end_time': datetime.datetime(2017, 9, 14, 21, 44, 50), 'detail': [{'ip': 'm17', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 55, 8), 'end_time': None, 'detail': [{'ip': 'm386', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 10, 49, 16), 'end_time': None, 'detail': [{'ip': 'm350', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 10, 53, 58), 'end_time': None, 'detail': [{'ip': 'm148', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 11, 5, 43), 'end_time': None, 'detail': [{'ip': 'm289', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 12, 55, 24), 'end_time': None, 'detail': [{'ip': 'm81', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 13, 12, 32), 'end_time': None, 'detail': [{'ip': 'm324', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 14, 6, 53), 'end_time': None, 'detail': [{'ip': 'm324', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 14, 14, 6), 'end_time': None, 'detail': [{'ip': 'm289', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 15, 3, 18), 'end_time': None, 'detail': [{'ip': 'm369', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 17, 23, 39), 'end_time': None, 'detail': [{'ip': 'm368', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 18, 8, 8), 'end_time': None, 'detail': [{'ip': 'm307', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 18, 18, 20), 'end_time': None, 'detail': [{'ip': 'm399', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 18, 34, 34), 'end_time': datetime.datetime(2017, 9, 27, 18, 43, 13), 'detail': [{'ip': 'm350', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 27, 19, 14, 5), 'end_time': datetime.datetime(2017, 10, 19, 22, 33, 14), 'detail': [{'ip': 'm182', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': None, 'end_time': datetime.datetime(2017, 10, 20, 0, 43, 53), 'detail': []}]), Job(job_id=application_1504131676014_3322,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-06 20:49:25,
# run_time=39109.01666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 6, 20, 52, 26), 'end_time': datetime.datetime(2017, 9, 14, 21, 52, 39), 'detail': [{'ip': 'm417', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 52, 45), 'end_time': datetime.datetime(2017, 10, 4, 0, 41, 27), 'detail': [{'ip': 'm409', 'gpus': ['gpu7']}]}]), Job(job_id=application_1504131676014_3356,
# user=2c46d5,
# status=Killed,
# num_gpus = 8,
# submitted_time = 2017-09-06 21:35:09,
# run_time=45816.95
# attempts=[{'start_time': datetime.datetime(2017, 9, 6, 21, 39, 8), 'end_time': None, 'detail': [{'ip': 'm265', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 14,
 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 14, 19, 2, 28), 'end_time': datetime.datetime(2017, 9, 14, 23, 2, 34), 'detail': [{'ip': 'm360', 'gpus': ['gpu2']}]}, {'start_time': datetime.datetime(2017, 9, 14, 23, 2, 40), 'end_time': datetime.datetime(2017, 10, 11, 21, 12, 15), 'detail': [{'ip': 'm76', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_4052,
# user=a547a3,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-08 02:33:17,
# run_time=53634.98333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 8, 2, 33, 30), 'end_time': datetime.datetime(2017, 10, 15, 3, 50, 47), 'detail': [{'ip': 'm153', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 10, 15, 3, 51, 1), 'end_time': datetime.datetime(2017, 10, 15, 8, 28, 29), 'detail': [{'ip': 'm278', 'gpus': ['gpu5']}]}]), Job(job_id=application_1504131676014_4140,
# user=a547a3,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-08 06:01:21,
# run_time=34856.316666666666
# attempts=[{'start_time': datetime.datetime(2017, 9, 8, 6, 1, 31), 'end_time': datetime.datetime(2017, 10, 2, 10, 57, 50), 'detail': [{'ip': 'm371', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_4181,
# user=1e93d0,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-08 06:52:04,
# run_time=86456.73333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 8, 6, 52, 18), 'end_time': datetime.datetime(2017, 9, 14, 9, 48, 12), 'detail': [{'ip': 'm417', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 14, 13, 55, 23), 'end_time': datetime.datetime(2017, 11, 7, 7, 49, 2), 'detail': [{'ip': 'm240', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_4182,
# user=1e93d0,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-08 06:52:07,
# run_time=81507.41666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 8, 6, 52, 18), 'end_time': datetime.datetime(2017, 11, 3, 21, 19, 43), 'detail': [{'ip': 'm372', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_4274,
# user=0e9bd9,
# status=Failed,
# num_gpus = 1,
# submitted_time = 2017-09-08 10:26:04,
# run_time=34279.26666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 8, 10, 26, 15), 'end_time': datetime.datetime(2017, 10, 1, 13, 42, 2), 'detail': [{'ip': 'm389', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 10, 1, 13, 42, 2), 'end_time': datetime.datetime(2017, 10, 1, 17, 42, 11), 'detail': [{'ip': 'm49', 'gpus': ['gpu5']}]}, {'start_time': datetime.datetime(2017, 10, 1, 17, 42, 11), 'end_time': datetime.datetime(2017, 10, 1, 21, 42, 19), 'detail': [{'ip': 'm95', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 10, 1, 21, 45, 23), 'end_time': datetime.datetime(2017, 10, 2, 1, 45, 21), 'detail': [{'ip': 'm95', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 10, 2, 1, 45, 34), 'end_time': datetime.datetime(2017, 10, 2, 5, 45, 31), 'detail': [{'ip': 'm72', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_4368,
# user=9b5f16,
# status=Killed,
# num_gpus = 8,
# submitted_time = 2017-09-08 18:05:01,
# run_time=86457.86666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 8, 18, 5, 13), 'end_time': None, 'detail': [{'ip': 'm77', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 14, 2, 3, 47), 'end_time': None, 'detail': [{'ip': 'm155', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}, {'start_time': datetime.datetime(2017, 9, 14, 4, 26, 43), 'end_time': datetime.datetime(2017, 11, 7, 19, 3, 5), 'detail': [{'ip': 'm382', 'gpus': ['gpu0', 'gpu1', 'gpu2', 'gpu3', 'gpu4', 'gpu5', 'gpu6', 'gpu7']}]}]), Job(job_id=application_1504131676014_5067,
# user=0e9bd9,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-10 07:21:26,
# run_time=30362.883333333335
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 7, 23, 36), 'end_time': datetime.datetime(2017, 10, 1, 9, 26, 29), 'detail': [{'ip': 'm60', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5104,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:07:46,
# run_time=34341.86666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 7, 57), 'end_time': datetime.datetime(2017, 9, 14, 20, 53, 6), 'detail': [{'ip': 'm232', 'gpus': ['gpu6']}]}, {'start_time': datetime.datetime(2017, 9, 14, 20, 53, 56), 'end_time': datetime.datetime(2017, 9, 15, 3, 3, 46), 'detail': [{'ip': 'm144', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 5, 1), 'end_time': datetime.datetime(2017, 10, 4, 5, 29, 49), 'detail': [{'ip': 'm49', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5110,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:16:39,
# run_time=34332.933333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 16, 47), 'end_time': datetime.datetime(2017, 9, 14, 20, 53, 14), 'detail': [{'ip': 'm232', 'gpus': ['gpu4']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 22, 4), 'end_time': datetime.datetime(2017, 9, 15, 0, 18, 11), 'detail': [{'ip': 'm245', 'gpus': ['gpu2']}]}, {'start_time': datetime.datetime(2017, 9, 15, 0, 18, 17), 'end_time': datetime.datetime(2017, 10, 4, 5, 29, 43), 'detail': [{'ip': 'm225', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5111,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:16:44,
# run_time=34332.88333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 16, 52), 'end_time': datetime.datetime(2017, 9, 15, 2, 57, 48), 'detail': [{'ip': 'm96', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 4, 55), 'end_time': datetime.datetime(2017, 10, 4, 5, 29, 45), 'detail': [{'ip': 'm396', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5112,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:16:50,
# run_time=34332.76666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 17, 2), 'end_time': datetime.datetime(2017, 9, 15, 0, 21, 31), 'detail': [{'ip': 'm377', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 15, 0, 21, 37), 'end_time': datetime.datetime(2017, 9, 15, 20, 45, 2), 'detail': [{'ip': 'm50', 'gpus': ['gpu5']}]}, {'start_time': datetime.datetime(2017, 9, 15, 20, 45, 9), 'end_time': datetime.datetime(2017, 9, 26, 4, 34, 26), 'detail': [{'ip': 'm284', 'gpus': ['gpu5']}]}, {'start_time': datetime.datetime(2017, 9, 26, 4, 37, 39), 'end_time': datetime.datetime(2017, 10, 4, 5, 29, 48), 'detail': [{'ip': 'm258', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5114,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:17:00,
# run_time=34332.65
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 17, 12), 'end_time': datetime.datetime(2017, 9, 15, 2, 56, 11), 'detail': [{'ip': 'm379', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 3, 39), 'end_time': datetime.datetime(2017, 10, 4, 5, 29, 51), 'detail': [{'ip': 'm226', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_5115,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:17:06,
# run_time=34332.61666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 17, 17), 'end_time': datetime.datetime(2017, 9, 15, 0, 18, 11), 'detail': [{'ip': 'm3', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 15, 0, 18, 17), 'end_time': datetime.datetime(2017, 10, 4, 5, 29, 54), 'detail': [{'ip': 'm53', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_5116,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:17:11,
# run_time=34332.566666666666
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 17, 22), 'end_time': datetime.datetime(2017, 9, 29, 10, 27, 31), 'detail': [{'ip': 'm3', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 29, 10, 27, 31), 'end_time': datetime.datetime(2017, 10, 4, 5, 29, 56), 'detail': [{'ip': 'm387', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_5117,
# user=66999e,
# status=Failed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:17:17,
# run_time=29430.283333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 17, 27), 'end_time': datetime.datetime(2017, 9, 14, 23, 24, 51), 'detail': [{'ip': 'm10', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 14, 23, 25, 43), 'end_time': datetime.datetime(2017, 9, 30, 19, 47, 44), 'detail': [{'ip': 'm136', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5120,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:17:33,
# run_time=34332.333333333336
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 17, 42), 'end_time': datetime.datetime(2017, 9, 14, 18, 57, 5), 'detail': [{'ip': 'm390', 'gpus': ['gpu6']}]}, {'start_time': datetime.datetime(2017, 9, 14, 20, 27, 59), 'end_time': datetime.datetime(2017, 9, 15, 2, 58, 44), 'detail': [{'ip': 'm53', 'gpus': ['gpu5']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 4, 23), 'end_time': datetime.datetime(2017, 9, 15, 12, 15, 21), 'detail': [{'ip': 'm6', 'gpus': ['gpu6']}]}, {'start_time': datetime.datetime(2017, 9, 15, 12, 15, 27), 'end_time': datetime.datetime(2017, 9, 16, 16, 47, 54), 'detail': [{'ip': 'm379', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 16, 16, 48, 2), 'end_time': datetime.datetime(2017, 10, 4, 5, 30, 2), 'detail': [{'ip': 'm389', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_5122,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:17:44,
# run_time=34332.25
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 17, 52), 'end_time': datetime.datetime(2017, 9, 14, 18, 57, 5), 'detail': [{'ip': 'm390', 'gpus': ['gpu2']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 3, 29), 'end_time': datetime.datetime(2017, 9, 15, 3, 1, 18), 'detail': [{'ip': 'm104', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 7, 6), 'end_time': datetime.datetime(2017, 10, 4, 5, 30, 7), 'detail': [{'ip': 'm157', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5123,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:17:49,
# run_time=34332.2
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 17, 57), 'end_time': datetime.datetime(2017, 9, 14, 12, 41, 32), 'detail': [{'ip': 'm220', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 14, 13, 26, 35), 'end_time': datetime.datetime(2017, 9, 15, 2, 52, 26), 'detail': [{'ip': 'm83', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 15, 2, 52, 33), 'end_time': datetime.datetime(2017, 10, 4, 5, 30, 9), 'detail': [{'ip': 'm135', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5125,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:17:59,
# run_time=34332.1
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 18, 7), 'end_time': datetime.datetime(2017, 9, 14, 23, 54, 47), 'detail': [{'ip': 'm328', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 14, 23, 55, 1), 'end_time': datetime.datetime(2017, 10, 4, 5, 30, 13), 'detail': [{'ip': 'm150', 'gpus': ['gpu5']}]}]), Job(job_id=application_1504131676014_5127,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:18:11,
# run_time=34331.916666666664
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 18, 22), 'end_time': datetime.datetime(2017, 10, 4, 5, 30, 17), 'detail': [{'ip': 'm5', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_5129,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:18:23,
# run_time=34328.71666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 21, 37), 'end_time': datetime.datetime(2017, 9, 10, 9, 22, 42), 'detail': [{'ip': 'm278', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 10, 9, 22, 47), 'end_time': datetime.datetime(2017, 9, 14, 23, 24, 51), 'detail': [{'ip': 'm213', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 15, 0, 1, 25), 'end_time': datetime.datetime(2017, 10, 4, 5, 30, 20), 'detail': [{'ip': 'm214', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_5132,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:18:39,
# run_time=34331.65
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 18, 47), 'end_time': datetime.datetime(2017, 9, 14, 21, 44, 50), 'detail': [{'ip': 'm238', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 14, 21, 55), 'end_time': datetime.datetime(2017, 9, 15, 3, 1, 47), 'detail': [{'ip': 'm124', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 4, 17), 'end_time': datetime.datetime(2017, 10, 4, 5, 30, 26), 'detail': [{'ip': 'm253', 'gpus': ['gpu3']}]}]), Job(job_id=application_1504131676014_5133,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:18:45,
# run_time=34331.51666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 18, 57), 'end_time': datetime.datetime(2017, 9, 14, 19, 51, 26), 'detail': [{'ip': 'm206', 'gpus': ['gpu0']}]}, {'start_time': datetime.datetime(2017, 9, 14, 19, 52, 8), 'end_time': datetime.datetime(2017, 9, 15, 3, 1, 47), 'detail': [{'ip': 'm224', 'gpus': ['gpu1']}]}, {'start_time': datetime.datetime(2017, 9, 15, 3, 7, 20), 'end_time': datetime.datetime(2017, 10, 4, 5, 30, 28), 'detail': [{'ip': 'm153', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5136,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:19:01,
# run_time=34331.36666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 10, 9, 19, 13), 'end_time': datetime.datetime(2017, 10, 4, 5, 30, 35), 'detail': [{'ip': 'm32', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_5137,
# user=66999e,
# status=Killed,
# num_gpus = 1,
# submitted_time = 2017-09-10 09:19:05,
# run_time=34331.4
# ...
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:03,
# run_time=4.633333333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 12, 19), 'end_time': datetime.datetime(2017, 9, 24, 15, 16, 57), 'detail': [{'ip': 'm145', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19919,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:17,
# run_time=5.383333333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 11, 31), 'end_time': datetime.datetime(2017, 9, 24, 15, 16, 54), 'detail': [{'ip': 'm285', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19920,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:20,
# run_time=4.816666666666666
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 9, 34), 'end_time': datetime.datetime(2017, 9, 24, 15, 14, 23), 'detail': [{'ip': 'm142', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19921,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:33,
# run_time=5.75
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 12, 46), 'end_time': datetime.datetime(2017, 9, 24, 15, 18, 31), 'detail': [{'ip': 'm219', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19922,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:34,
# run_time=3.0833333333333335
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 9, 46), 'end_time': datetime.datetime(2017, 9, 24, 15, 12, 51), 'detail': [{'ip': 'm63', 'gpus': ['gpu6']}]}]), Job(job_id=application_1504131676014_19923,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:37,
# run_time=2.9166666666666665
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 9, 47), 'end_time': datetime.datetime(2017, 9, 24, 15, 12, 42), 'detail': [{'ip': 'm115', 'gpus': ['gpu7']}]}]), Job(job_id=application_1504131676014_19924,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:39,
# run_time=3.4166666666666665
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 9, 53), 'end_time': datetime.datetime(2017, 9, 24, 15, 13, 18), 'detail': [{'ip': 'm115', 'gpus': ['gpu5']}]}]), Job(job_id=application_1504131676014_19925,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:42,
# run_time=2.8833333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 9, 53), 'end_time': datetime.datetime(2017, 9, 24, 15, 12, 46), 'detail': [{'ip': 'm416', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19926,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:53,
# run_time=2.9166666666666665
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 12, 6), 'end_time': datetime.datetime(2017, 9, 24, 15, 15, 1), 'detail': [{'ip': 'm184', 'gpus': ['gpu2']}]}]), Job(job_id=application_1504131676014_19927,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:09:56,
# run_time=4.916666666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 12, 5), 'end_time': datetime.datetime(2017, 9, 24, 15, 17), 'detail': [{'ip': 'm251', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19928,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:10:12,
# run_time=5.833333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 12, 25), 'end_time': datetime.datetime(2017, 9, 24, 15, 18, 15), 'detail': [{'ip': 'm359', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19929,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:10:50,
# run_time=5.933333333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 12, 59), 'end_time': datetime.datetime(2017, 9, 24, 15, 18, 55), 'detail': [{'ip': 'm213', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19930,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:10:58,
# run_time=2.95
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 11, 11), 'end_time': datetime.datetime(2017, 9, 24, 15, 14, 8), 'detail': [{'ip': 'm284', 'gpus': ['gpu2']}]}]), Job(job_id=application_1504131676014_19931,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:11:15,
# run_time=3.05
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 13, 25), 'end_time': datetime.datetime(2017, 9, 24, 15, 16, 28), 'detail': [{'ip': 'm49', 'gpus': ['gpu6']}]}]), Job(job_id=application_1504131676014_19932,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:11:25,
# run_time=2.783333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 11, 38), 'end_time': datetime.datetime(2017, 9, 24, 15, 14, 25), 'detail': [{'ip': 'm284', 'gpus': ['gpu4']}]}]), Job(job_id=application_1504131676014_19933,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:11:31,
# run_time=2.7333333333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 14, 44), 'end_time': datetime.datetime(2017, 9, 24, 15, 17, 28), 'detail': [{'ip': 'm416', 'gpus': ['gpu7']}]}]), Job(job_id=application_1504131676014_19934,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:11:34,
# run_time=2.8666666666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 50), 'end_time': datetime.datetime(2017, 9, 24, 15, 19, 42), 'detail': [{'ip': 'm270', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19935,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:11:45,
# run_time=2.85
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 11, 52), 'end_time': datetime.datetime(2017, 9, 24, 15, 14, 43), 'detail': [{'ip': 'm284', 'gpus': ['gpu7']}]}]), Job(job_id=application_1504131676014_19936,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:11:54,
# run_time=4.75
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 13, 6), 'end_time': datetime.datetime(2017, 9, 24, 15, 17, 51), 'detail': [{'ip': 'm209', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19937,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:11:56,
# run_time=2.95
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 14, 5), 'end_time': datetime.datetime(2017, 9, 24, 15, 17, 2), 'detail': [{'ip': 'm416', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19938,
# user=066e99,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:11:57,
# run_time=1.2666666666666666
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 12, 6), 'end_time': datetime.datetime(2017, 9, 24, 15, 13, 22), 'detail': [{'ip': 'm142', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19939,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:12:05,
# run_time=2.85
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 13, 19), 'end_time': datetime.datetime(2017, 9, 24, 15, 16, 10), 'detail': [{'ip': 'm253', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19940,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:12:17,
# run_time=2.816666666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 14, 31), 'end_time': datetime.datetime(2017, 9, 24, 15, 17, 20), 'detail': [{'ip': 'm184', 'gpus': ['gpu7']}]}]), Job(job_id=application_1504131676014_19941,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:12:22,
# run_time=4.666666666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 12, 32), 'end_time': datetime.datetime(2017, 9, 24, 15, 17, 12), 'detail': [{'ip': 'm383', 'gpus': ['gpu3']}]}]), Job(job_id=application_1504131676014_19942,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:12:26,
# run_time=4.45
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 12, 39), 'end_time': datetime.datetime(2017, 9, 24, 15, 17, 6), 'detail': [{'ip': 'm31', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19943,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:12:31,
# run_time=2.783333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 14, 45), 'end_time': datetime.datetime(2017, 9, 24, 15, 17, 32), 'detail': [{'ip': 'm364', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19944,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:12:36,
# run_time=3.033333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 13, 46), 'end_time': datetime.datetime(2017, 9, 24, 15, 16, 48), 'detail': [{'ip': 'm313', 'gpus': ['gpu7']}]}]), Job(job_id=application_1504131676014_19945,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:12:42,
# run_time=4.833333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 14, 52), 'end_time': datetime.datetime(2017, 9, 24, 15, 19, 42), 'detail': [{'ip': 'm70', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19946,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:12:54,
# run_time=2.933333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 15, 5), 'end_time': datetime.datetime(2017, 9, 24, 15, 18, 1), 'detail': [{'ip': 'm115', 'gpus': ['gpu7']}]}]), Job(job_id=application_1504131676014_19947,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:13:13,
# run_time=2.816666666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 15, 24), 'end_time': datetime.datetime(2017, 9, 24, 15, 18, 13), 'detail': [{'ip': 'm409', 'gpus': ['gpu5']}]}]), Job(job_id=application_1504131676014_19948,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:13:37,
# run_time=4.4
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 50), 'end_time': datetime.datetime(2017, 9, 24, 15, 21, 14), 'detail': [{'ip': 'm266', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19949,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:14:05,
# run_time=2.8666666666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 16), 'end_time': datetime.datetime(2017, 9, 24, 15, 19, 8), 'detail': [{'ip': 'm63', 'gpus': ['gpu6']}]}]), Job(job_id=application_1504131676014_19950,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:14:10,
# run_time=5.033333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 23), 'end_time': datetime.datetime(2017, 9, 24, 15, 21, 25), 'detail': [{'ip': 'm285', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19951,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:14:19,
# run_time=4.783333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 17, 32), 'end_time': datetime.datetime(2017, 9, 24, 15, 22, 19), 'detail': [{'ip': 'm326', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19952,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:14:27,
# run_time=2.8333333333333335
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 37), 'end_time': datetime.datetime(2017, 9, 24, 15, 19, 27), 'detail': [{'ip': 'm115', 'gpus': ['gpu5']}]}]), Job(job_id=application_1504131676014_19953,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:14:47,
# run_time=5.766666666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 15, 57), 'end_time': datetime.datetime(2017, 9, 24, 15, 21, 43), 'detail': [{'ip': 'm62', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19954,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:14:51,
# run_time=2.9833333333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 14, 58), 'end_time': datetime.datetime(2017, 9, 24, 15, 17, 57), 'detail': [{'ip': 'm416', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19955,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:15:07,
# run_time=4.85
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 16), 'end_time': datetime.datetime(2017, 9, 24, 15, 21, 7), 'detail': [{'ip': 'm304', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19956,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:15:09,
# run_time=3.0
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 17, 18), 'end_time': datetime.datetime(2017, 9, 24, 15, 20, 18), 'detail': [{'ip': 'm49', 'gpus': ['gpu2']}]}]), Job(job_id=application_1504131676014_19958,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:15:16,
# run_time=4.75
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 29), 'end_time': datetime.datetime(2017, 9, 24, 15, 21, 14), 'detail': [{'ip': 'm32', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19957,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:15:16,
# run_time=4.783333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 23), 'end_time': datetime.datetime(2017, 9, 24, 15, 21, 10), 'detail': [{'ip': 'm344', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19959,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:15:20,
# run_time=4.8
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 18, 35), 'end_time': datetime.datetime(2017, 9, 24, 15, 23, 23), 'detail': [{'ip': 'm213', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19960,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:15:23,
# run_time=2.933333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 18, 35), 'end_time': datetime.datetime(2017, 9, 24, 15, 21, 31), 'detail': [{'ip': 'm409', 'gpus': ['gpu4']}]}]), Job(job_id=application_1504131676014_19961,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:15:30,
# run_time=3.55
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 15, 44), 'end_time': datetime.datetime(2017, 9, 24, 15, 19, 17), 'detail': [{'ip': 'm131', 'gpus': ['gpu2']}]}]), Job(job_id=application_1504131676014_19962,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:15:35,
# run_time=2.783333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 22, 1), 'end_time': datetime.datetime(2017, 9, 24, 15, 24, 48), 'detail': [{'ip': 'm115', 'gpus': ['gpu5']}]}]), Job(job_id=application_1504131676014_19963,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:15:54,
# run_time=2.966666666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 4), 'end_time': datetime.datetime(2017, 9, 24, 15, 19, 2), 'detail': [{'ip': 'm17', 'gpus': ['gpu6']}]}]), Job(job_id=application_1504131676014_19964,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:16:04,
# run_time=2.816666666666667
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 17, 18), 'end_time': datetime.datetime(2017, 9, 24, 15, 20, 7), 'detail': [{'ip': 'm17', 'gpus': ['gpu3']}]}]), Job(job_id=application_1504131676014_19965,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:16:08,
# run_time=4.683333333333334
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 16, 23), 'end_time': datetime.datetime(2017, 9, 24, 15, 21, 4), 'detail': [{'ip': 'm142', 'gpus': ['gpu1']}]}]), Job(job_id=application_1504131676014_19966,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:16:15,
# run_time=4.85
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 17, 25), 'end_time': datetime.datetime(2017, 9, 24, 15, 22, 16), 'detail': [{'ip': 'm142', 'gpus': ['gpu0']}]}]), Job(job_id=application_1504131676014_19967,
# user=ae8ed1,
# status=Pass,
# num_gpus = 1,
# submitted_time = 2017-09-24 15:16:18,
# run_time=4.783333333333333
# attempts=[{'start_time': datetime.datetime(2017, 9, 24, 15, 19, 29), 'end_time': datetime.datetime(2017, 9, 24, 15, 24, 16), 'detail': [{'ip': 'm304', 'gpus': ['gpu1']}]}])]

# %%
# Plotting Job CDF for Phillly Trace
run_times = []
for j in jobs:
    if j._run_time is not None and j.status=='Pass':
        run_times.append(j._run_time)
run_times.sort()
#print(run_times)

# buckets = sorted([bucket for bucket in run_times])
# for bucket in buckets:
#     num_gpus, color, linestyle = get_plot_config_from_bucket(bucket)
x, y = get_cdf(run_times)
plt.plot(x, y)
plt.legend(loc='lower right')
plt.xscale('log')
plt.xlim(10 ** -1, 8* 10 ** 4)
plt.ylim(0, 100)
plt.xlabel('Time (min)')
plt.ylabel('CDF')
plt.grid(alpha=.3, linestyle='--')
plt.show()
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.

# %%
# Problem V0: Global Deadline, jobs run on one node

# Ensure max runtime is 100 hours for jobs (off of Philly trace)
run_times = [r for r in run_times if r<=6000.0]

from random import choices
subsampled_run_times =  choices(run_times, k=1000)
print(subsampled_run_times)
print(sum(subsampled_run_times)/(60*8))
# Out:
# [66.13333333333334, 98.51666666666667, 36.016666666666666, 5.366666666666666, 75.01666666666667, 1.2666666666666666, 1.15, 1.7666666666666666, 1.9666666666666666, 0.7666666666666667, 40.95, 17.183333333333334, 103.0, 1.7333333333333334, 31.866666666666667, 21.216666666666665, 82.0, 41.983333333333334, 19.516666666666666, 22.116666666666667, 152.23333333333332, 35.1, 1.0333333333333334, 96.98333333333333, 1.0833333333333333, 50.583333333333336, 38.85, 9.166666666666666, 0.8166666666666667, 1.7833333333333334, 334.9, 9.666666666666666, 41.28333333333333, 77.0, 41.43333333333333, 149.7, 36.63333333333333, 6.083333333333333, 20.6, 25.55, 72.45, 41.06666666666667, 179.55, 3.1666666666666665, 442.85, 19.4, 3250.616666666667, 23.016666666666666, 97.8, 28.2, 9.25, 28.616666666666667, 54.983333333333334, 2.8333333333333335, 24.05, 2.216666666666667, 0.45, 3.35, 24.1, 12.95, 134.28333333333333, 1.2, 31.95, 34.516666666666666, 32.43333333333333, 76.76666666666667, 1.1, 0.9666666666
# 361.48899305555534

# %%
def greedy_solver_v0(num_nodes, run_times, global_deadline):
    # Shortest Job First
    run_times = [r/60.0 for r in run_times]
    run_times.sort()
    num_nodes_capacity = [0.0] * num_nodes
    num_nodes_jobs = [[]]*num_nodes
    cloud_cost = sum(run_times)
    for time in run_times:
        bin_idx = 0
        min_bin_idx = num_nodes_capacity.index(min(num_nodes_capacity))
        # Place in bin with least capacity
        if global_deadline - num_nodes_capacity[min_bin_idx] >= time:
            num_nodes_capacity[min_bin_idx] += time
            num_nodes_jobs[min_bin_idx].append(time)
            cloud_cost -= time
    return cloud_cost, num_nodes_capacity

def ilp_solver_v0(num_nodes, run_times, global_deadline):
    import cvxpy
    import numpy as np
    run_times = [r/60.0 for r in run_times]
    num_jobs = len(run_times)
    weights = np.array(run_times).reshape((num_jobs, 1))
    utilities = np.array(run_times).reshape((num_jobs, 1))
    global_deadline = np.array([global_deadline] * num_nodes).reshape((num_nodes, 1))

    # Optimization varaibles that indicates 0/1 if job goes to node_idx
    selection = cvxpy.Variable((num_nodes, num_jobs), boolean=True)

    # The sum of the weights should be less than or equal to the deadline
    weight_constraint = selection@weights  <= global_deadline
    
    bin_constraint = cvxpy.sum(selection, axis=0) <= 1

    # Our total utility is the sum of the item utilities
    total_utility = cvxpy.sum(selection@utilities)

    # We tell cvxpy that we want to maximize total utility 
    # subject to weight_constraint. All constraints in 
    # cvxpy must be passed as a list
    multi_knapsack_problem = cvxpy.Problem(cvxpy.Maximize(total_utility), [weight_constraint, bin_constraint])

    # Solving the problem
    opts = {'limits/time' : 600} #{'maxiters' : 5000}
    multi_knapsack_problem.solve(solver=cvxpy.SCIP, verbose=True, scip_params = opts)
    
    solution = selection.value
    total_weight = solution @ weights
    return sum(run_times) - np.sum(total_weight), total_weight.reshape((num_nodes, ))

cluster_size = [2, 4, 8, 16]
deadline_fraction = [0.8, 0.85, 0.9, 0.95, 1, 1.05]

results = {}
for c_size in cluster_size:
    max_deadline = sum(subsampled_run_times)/(60*c_size)
    results[c_size] = {}
    for ddl in deadline_fraction:
        print(f'{c_size} + {ddl}')
        results[c_size][ddl] = {}
        results[c_size][ddl]['greedy'] = greedy_solver_v0(c_size, subsampled_run_times, max_deadline * ddl)[0]
        results[c_size][ddl]['ilp'] = ilp_solver_v0(c_size, subsampled_run_times, max_deadline * ddl)[0]
        print(results)
# Out:
# 2 + 0.8
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Jan 19 04:44:02 AM: Your problem has 2000 variables, 2 constraints, and 0 parameters.
# (CVXPY) Jan 19 04:44:02 AM: It is compliant with the following grammars: DCP, DQCP
# (CVXPY) Jan 19 04:44:02 AM: (If you need to solve this problem multiple times, but with different data, consider using parameters.)
# (CVXPY) Jan 19 04:44:02 AM: CVXPY will first compile your problem; then, it will invoke a numerical solver to obtain a solution.
# -------------------------------------------------------------------------------
#                                   Compilation
# -------------------------------------------------------------------------------
# (CVXPY) Jan 19 04:44:02 AM: Compiling problem (target solver=SCIP).
# (CVXPY) Jan 19 04:44:02 AM: Reduction chain: FlipObjective -> Dcp2Cone -> CvxAttr2Constr -> ConeMatrixStuffing -> SCIP
# (CVXPY) Jan 19 04:44:02 AM: Applying reduction FlipObjective
# (CVXPY) Jan 19 04:44:02 AM: Applying reduction Dcp2Cone
# (CVXPY) Jan 19 04:44:02 AM: Applying reduction CvxAttr2Constr
# (CVXPY) Jan 19 04:44:02 AM: Applying reduction ConeMatrixStuffing
# (CVXPY) Jan 19 04:44:02 AM: Applying reduction SCIP
# (CVXPY) Jan 19 04:44:02 AM: Finished problem compilation (took 2.578e-02 seconds).
# -------------------------------------------------------------------------------
#                                 Numerical solver
# -------------------------------------------------------------------------------
# (CVXPY) Jan 19 04:44:02 AM: Invoking solver SCIP  to obtain a solution.
# -------------------------------------------------------------------------------
#                                     Summary
# -------------------------------------------------------------------------------
# (CVXPY) Jan 19 04:44:04 AM: Problem status: optimal
# (CVXPY) Jan 19 04:44:04 AM: Optimal value: 2.314e+03
# (CVXPY) Jan 19 04:44:04 AM: Compilation took 2.578e-02 seconds
# (CVXPY) Jan 19 04:44:04 AM: Solver (including time spent in interface) took 1.709e+00 seconds
# {2: {0.8: {'greedy': 642.5094444444467, 'ilp': 578.3813888888826}}}
# 2 + 0.85
# ===============================================================================
#                                      CVXPY
#                                      v1.3.0
# ===============================================================================
# (CVXPY) Jan 19 04:44:04 AM: Your problem has 2000 variables, 2 constraints, and 0 parameters.
# (CVXPY) Jan 19 04
fig, ax = plt.subplots()

a = []
import math
for clus_size in [16,8,4,2]:
    b = []
    for ddl in [0.8, 0.85, 0.9, 0.95, 1, 1.05]:
        t_dict = optimal_results[clus_size][ddl]
        fraction = t_dict['greedy']/t_dict['ilp']
        if abs(t_dict['greedy']-0)<1e-2:
            fraction = 8
        elif fraction > 100 or fraction < -100:
            fraction = 8
        b.append(fraction)
    a.append(b)

print(a)
plt.imshow(a, interpolation='nearest')

# We need to draw the canvas, otherwise the labels won't be positioned and 
# won't have values yet.
fig.canvas.draw()
labels = [item.get_text() for item in ax.get_xticklabels()]
labels = ['', '0.8', '0.85', '0.9', '0.95', '1', '1.05' ]
ax.set_xticklabels(labels)


labels = [item.get_text() for item in ax.get_yticklabels()]
labels = ['', '16', '', '8', '', '4', '', '2']
ax.set_yticklabels(labels)

plt.xlabel('Global Deadline')

plt.ylabel('Number of Local Nodes')

plt.title('Greedy/ILP Ratio')
plt.show()
# Out:
# [[1.7216997193805332, 2.0350080460234095, 2.652651588282756, 4.8911510391955, 8, 8], [1.4270417802896935, 1.6303909879011567, 1.9878559854153137, 3.005501894157812, 8, 8], [1.2227942197037185, 1.3252394451698466, 1.5027624946210425, 1.972211763078702, 8, 8], [1.1108750329583723, 1.164465123665518, 1.2466928828302948, 1.97221555183731, 8, 8]]
# /Users/michaelluo/opt/anaconda3/envs/ray/lib/python3.7/site-packages/ipykernel_launcher.py:28: UserWarning: FixedFormatter should only be used together with FixedLocator
# /Users/michaelluo/opt/anaconda3/envs/ray/lib/python3.7/site-packages/ipykernel_launcher.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# importing package
import matplotlib.pyplot as plt
  
  
# plot lines
x = [0.8, 0.85, 0.9, 0.95, 1, 1.05]
for clus_size in [2,4,8,16]:
    y = []
    for ddl in x:
        y.append(optimal_results[clus_size][ddl]['greedy']/optimal_results[clus_size][x[0]]['greedy'])
    plt.plot(x, y, label = f"{clus_size} Nodes")
plt.xlabel('DDL')
plt.ylabel('Normalized Cost')
plt.legend()
plt.title('Greedy w.r. Nodes')
plt.show()

x = [0.8, 0.85, 0.9, 0.95, 1, 1.05]
for clus_size in [2,4,8,16]:
    y = []
    for ddl in x:
        y.append(optimal_results[clus_size][ddl]['ilp']/optimal_results[clus_size][x[0]]['ilp'])
    plt.plot(x, y, label = f"{clus_size} Nodes")
plt.xlabel('DDL')
plt.ylabel('Normalized Cost')
plt.legend()
plt.title('ILP w.r. Nodes')
plt.show()

# %%
x = [0.8, 0.85, 0.9, 0.95, 1, 1.05]
for alg in ['greedy', 'ilp']:
    y=[]
    for ddl in x:
        y.append(optimal_results[16][ddl][alg])
    plt.plot(x, y, label = f"{alg}")
plt.xlabel('DDL')
plt.ylabel('Cost')
plt.legend()
plt.title('Greedy vs ILP (16 Nodes)')
plt.show()

x = [0.8, 0.85, 0.9, 0.95, 1, 1.05]
for alg in ['greedy', 'ilp']:
    y=[]
    for ddl in x:
        y.append(optimal_results[8][ddl][alg])
    plt.plot(x, y, label = f"{alg}")
plt.xlabel('DDL')
plt.ylabel('Cost')
plt.legend()
plt.title('Greedy vs ILP (16 Nodes)')
plt.show()
