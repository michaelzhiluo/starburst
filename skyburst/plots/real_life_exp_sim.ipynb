# %%
import numpy as np
# This Starburst "time estimator" for our fine-tuning jobs in our real-world section (6.2).
ESTIMATED_TIMES = [
# LANGUAGE
(0, 181, 4, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 16 --hidden_size 128 --num_hidden_layers 2 --num_attention_heads 4 --gradient_accumulation_steps 2'), 
(1, 182, 8, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 16 --hidden_size 128 --num_hidden_layers 2 --num_attention_heads 4 --gradient_accumulation_steps 2'), 
(2, 197, 4, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 16 --hidden_size 128 --num_hidden_layers 2 --num_attention_heads 4'), 
(3, 188, 8, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 16 --hidden_size 128 --num_hidden_layers 2 --num_attention_heads 4'), 
(4, 226, 4, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 8 --hidden_size 512 --num_hidden_layers 4 --num_attention_heads 8'), 
(5, 235, 8, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 8 --hidden_size 512 --num_hidden_layers 4 --num_attention_heads 8'), 
(6, 4821, 4, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 16 --hidden_size 128 --num_hidden_layers 2 --num_attention_heads 4 --gradient_accumulation_steps 2'), 
(7, 7383, 8, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 16 --hidden_size 128 --num_hidden_layers 2 --num_attention_heads 4 --gradient_accumulation_steps 2'), 
(8, 8505, 4, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 16 --hidden_size 256 --num_hidden_layers 4 --num_attention_heads 4'), 
(9, 7760, 8, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 16 --hidden_size 256 --num_hidden_layers 4 --num_attention_heads 4'), 
(10, 11972, 4, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 8 --hidden_size 512 --num_hidden_layers 4 --num_attention_heads 8'), 
(12, 330, 4, '/tasks/huggingface-gpt-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 8 --n_embd 256 --n_layer 4 --n_head 4  --gradient_accumulation_steps 2'), 
(14, 531, 4, '/tasks/huggingface-gpt-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 8 --n_embd 512 --n_layer 8 --n_head 8'), 
(16, 15342, 4, '/tasks/huggingface-gpt-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 8 --n_embd 256 --n_layer 4 --n_head 4 --gradient_accumulation_steps 2'), 
#(18, 28825, 4, '/tasks/huggingface-gpt-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 8 --n_embd 512 --n_layer 8 --n_head 8'), 
(11, 9751, 8, '/tasks/huggingface-bert-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 8 --hidden_size 512 --num_hidden_layers 4 --num_attention_heads 8'), 
(15, 417, 8, '/tasks/huggingface-gpt-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 8 --n_embd 512 --n_layer 8 --n_head 8'), 
(22, 6523, 4, '/tasks/huggingface-gpt-wmt16.py --language_pair fi-en --per_device_train_batch_size 8 --n_embd 256 --n_layer 4 --n_head 4 --gradient_accumulation_steps 2'), 
(13, 299, 8, '/tasks/huggingface-gpt-wikitext.py --dataset wikitext-2 --per_device_train_batch_size 8 --n_embd 256 --n_layer 4 --n_head 4  --gradient_accumulation_steps 2'), 
(17, 11920, 8, '/tasks/huggingface-gpt-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 8 --n_embd 256 --n_layer 4 --n_head 4 --gradient_accumulation_steps 2'), 
(24, 8522, 4, '/tasks/huggingface-gpt-wmt16.py --language_pair fi-en --per_device_train_batch_size 8 --n_embd 512 --n_layer 8 --n_head 8'),
(19, 18116, 8, '/tasks/huggingface-gpt-wikitext.py --dataset wikitext-103 --per_device_train_batch_size 8 --n_embd 512 --n_layer 8 --n_head 8'), 
(23, 5554, 8, '/tasks/huggingface-gpt-wmt16.py --language_pair fi-en --per_device_train_batch_size 8 --n_embd 256 --n_layer 4 --n_head 4 --gradient_accumulation_steps 2'),
(25, 10889, 8, '/tasks/huggingface-gpt-wmt16.py --language_pair fi-en --per_device_train_batch_size 8 --n_embd 512 --n_layer 8 --n_head 8'), 
# VISION 
(26, 114, 1, '/tasks/pytorch-cifar10-efficientnet_v2_m.py --num_train_epochs 1'),
(28, 98, 2, '/tasks/pytorch-cifar10-efficientnet_v2_m.py --num_train_epochs
 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 94'),
(59, 7152, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 96'),
(59, 7301, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 98'),
(59, 7450, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 100'),
(59, 7599, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 102'),
(59, 7748, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 104'),
(59, 7897, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 106'),
(59, 8046, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 108'),
(59, 8195, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 110'),
(59, 8344, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 112'),
(59, 8493, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 114'),
(59, 8642, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 116'),
(59, 8791, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 118'),
(59, 8940, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 120'),
(59, 9089, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 122'),
(59, 9238, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 124'),
(59, 9387, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 126'),
(59, 9536, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 128'),
(59, 9685, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 130'),
(59, 9834, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 132'),
(59, 9983, 1, '/tasks/pytorch-cifar10-resnext50_32x4d.py --num_train_epochs 134'),

# 1 vgg
(67, 150, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 2'),
(67, 300, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 4'),
(67, 450, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 6'),
(67, 600, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 8'),
(67, 750, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 10'),
(67, 900, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 12'),
(67, 1050, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 14'),
(67, 1200, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 16'),
(67, 1350, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 18'),
(67, 1500, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 20'),
(67, 1650, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 22'),
(67, 1800, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 24'),
(67, 1950, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 26'),
(67, 2100, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 28'),
(67, 2250, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 30'),
(67, 2400, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 32'),
(67, 2550, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 34'),
(67, 2700, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 36'),
(67, 2850, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 38'),
(67, 3000, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 40'),
(67, 3150, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 42'),
(67, 3300, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 44'),
(67, 3450, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 46'),
(67, 3600, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 48'),
(67, 3750, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 50'),
(67, 3900, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 52'),
(67, 4050, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 54'),
(67, 4200, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 56'),
(67, 4350, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 58'),
(67, 4500, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 60'),
(67, 4650, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 62'),
(67, 4800, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 64'),
(67, 4950, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 66'),
(67, 5100, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 68'),
(67, 5250, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 70'),
(67, 5400, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 72'),
(67, 5550, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 74'),
(67, 5700, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 76'),
(67, 5850, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 78'),
(67, 6000, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 80'),
(67, 6150, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 82'),
(67, 6300, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 84'),
(67, 6450, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 86'),
(67, 6600, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 88'),
(67, 6750, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 90'),
(67, 6900, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 92'),
(67, 7050, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 94'),
(67, 7200, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 96'),
(67, 7350, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 98'),
(67, 7500, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 100'),
(67, 7650, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 102'),
(67, 7800, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 104'),
(67, 7950, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 106'),
(67, 8100, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 108'),
(67, 8250, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 110'),
(67, 8400, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 112'),
(67, 8550, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 114'),
(67, 8700, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 116'),
(67, 8850, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 118'),
(67, 9000, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 120'),
(67, 9150, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 122'),
(67, 9300, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 124'),
(67, 9450, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 126'),
(67, 9600, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 128'),
(67, 9750, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 130'),
(67, 9900, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 132'),
(67, 10050, 1, '/tasks/pytorch-cifar10-vgg11.py --num_train_epochs 134'),
]

ESTIMATED_TIMES = [(s[0], s[1]/3600.0, s[2], s[3]) for s in ESTIMATED_TIMES]
def get_training_jobs(gpu):
    """returns list of runtimes and jobs with specified number of gpus"""
    valid_jobs = []
    for job in ESTIMATED_TIMES: 
        if job[2] == gpu: 
            valid_jobs.append((job[1], job[3]))
    return valid_jobs

def sample_training_job(gpu, runtime):
    "return script the closest fils gpu runtime pair"
    jobs = get_training_jobs(gpu)
    #id = 0
    min_delta = math.inf
    min_id = 0  
    for i in range(len(jobs)):
        job = jobs[i]
        delta = abs(jobs[i][0] - runtime)
        if delta <= min_delta: 
            min_delta = delta
            min_id = i
    return jobs[min_id]

# %%
def generate_surya_jobs(arrival_rate=8.0,
                            job_runtime=0.75,
                            total_jobs=100,
                            seed=2024):
    """Generates GPU jobs based on a Poisson arrival distribution and exponential runtime distribution.
    """
    np.random.seed(seed)
    submit_time = 0
    job_list = []
    categorical = [0.7, 0.15, 0.1, 0.05]
    sizes = [1, 2, 4, 8]
    idx=0
    while True:
        resources_dict = {'GPUs': np.random.choice(sizes, p=categorical)}
        submit_time += max(3, np.random.exponential(scale = 3600/arrival_rate ))/3600#max(3/3600.0, np.random.exponential(scale=1/arrival_rate))
        print(submit_time * 3600)
        # Run time for jobs
        run = np.random.exponential(scale=job_runtime)
        run = max(30/3600.0, run)
        run = min(10000/3600.0, run)
        
        # Get GPU resources
        
        real_tuple = sample_training_job(resources_dict['GPUs'], run)
        #print(real_tuple)
        cost = resources_dict['GPUs'] * real_tuple[0]
        job_list.append(
            Job(idx,
                arrival=submit_time,
                runtime=real_tuple[0],
                resources=resources_dict,
                cost=cost))
        
        idx+=1
        if submit_time > 3:
            break
    return job_list

# %%
import copy
import csv
import cvxpy
import datetime
import json
import math
import matplotlib.pyplot as plt
import multiprocessing
from multiprocessing import Pool
import numpy as np
import os
import pandas as pd
import pickle
import random
import seaborn as sns
from typing import List, Dict
import sys
sys.path.append('../../')

from skyburst import Job
from skyburst.plot import *
from skyburst.traces import philly
from skyburst.traces import philly_utils
from skyburst import job_gen
from skyburst.simulator import run_simulator

run_config = {
    # Size of the cluster (i.e. # of cluster nodes).
    'cluster_size': 4,
    # Number of GPU(s) per cluster node.
    'gpus_per_node': 8,
    # Number of CPU(s) per cluster node.
    'cpus_per_node': 48,
    # Scheduling algorithm specifying order of the queue.
    'sched_alg': 'fifo',
    # How jobs are binpacked into the cluster.
    'binpack_alg': 'best-fit',
    # Waiting policy (how long jobs should wait in the cloud).
    'waiting_policy': 'linear_runtime',
    # Waiting hyperparameter (to be passed to waiting_policy)
    'waiting_factor': 1.25,
    # Sets clipping time for waiting (max time a job should wait)
    'clip_time': 1e9,
    # Enable backfill (assumes time estimator).
    'backfill': False,
    # Enable loop scheduling (just loop through entire queue, remove HoL).
    'loop': False,
    # Enable prediction. (Jobs predict if they can be assigned to cluster before timing out).
    # 0 is no prediction, 1 is perfect oracle
    'predict_wait': 0,
    # Queue length
    'max_queue_length': -1,
    # Time estimator error
    'time_estimator_error': 0,
    # (Deprecated) Algorithm to immediately send job to cloud (without waiting).
    'filter_alg': None,
    # Prints out simulator state at every timestep.
    'verbose': False,
    # Appends python debugger at every timestemp.
    'debug': False,
    # Position for TQDM progress tracker bar.
    'pbar_idx': 0,
    # Jobs to not consider for final metrics at the beg. and end. of simulator.
    'warmup_jobs': 10,
    # Whether to get snapshots and save to result dict
    'snapshot': False,
    # Metadata on job generation (run prior to simulator).
    'jobgen_spec': {
        # Dataset type ['philly', 'philly_gen', 'gen_gpu']
        'dataset': '',
        # Arrival rate of jobs (used in 'gen_gpu', 'philly_gen')
        'arrival_rate': -1,
        # Total number of jobs generated.
        'total_jobs': -1,
        # Avg. Job runtime (used in 'gen_gpu')
        'job_runtime': -1,
    }
}
from skyburst.traces import philly
#philly_jobs = philly.load_philly_traces('~/philly-traces/trace-data')
#jobs_100 = job_gen.generate_synthetic_jobs(arrival_rate=15, total_jobs=150, seed=0)#np.random.seed())

# High system util
jobs_100 = generate_surya_jobs(arrival_rate=24.5, job_runtime=0.75, total_jobs=89, seed=13)
run_config['warmup_jobs'] = 0
print(len(jobs_100))
# Overloaded system
# jobs_100 = generate_surya_jobs(arrival_rate=32, job_runtime=0.75, total_jobs=164, seed=13)
# #Overloaded needs a longer warmup period.
# run_config['warmup_jobs'] = 10
# print(len(jobs_100))
# jobs_100
# Out:
# 39.850799660668535
# 568.4267389080111
# 787.9529291981312
# 793.1935046189138
# 1079.0389283491957
# 1122.5461172213165
# 1187.7409448332735
# 1244.2782588774073
# 1254.1671161765462
# 1257.1671161765464
# 1268.7367021210518
# 1364.7909096119183
# 1406.4718221739217
# 1454.1300940972933
# 1495.323400694762
# 1565.4074722289301
# 1575.7422560518708
# 1597.56028797335
# 1621.7498043685423
# 1661.6232889276762
# 1672.719851077449
# 1695.716200184624
# 1878.637260056535
# 1980.206099971951
# 2046.916001915915
# 2068.4568377813
# 2190.406551143672
# 2210.693677940122
# 2239.0906200141635
# 2741.4665408888177
# 2904.107879566661
# 3402.9763933430713
# 3449.0958047747736
# 3624.4106295112783
# 3663.5089188739717
# 3835.083614731838
# 3845.368180721863
# 3864.8650235143587
# 3869.920733967658
# 4079.569929649004
# 4437.120865225161
# 4440.120865225161
# 4452.328161851591
# 4574.357981240754
# 4589.597941580854
# 5032.369501766401
# 5241.138914642121
# 5428.562120850076
# 5454.415777420103
# ...

# %%
# NO WAIT
run_config['waiting_policy'] = 'constant'
# 15 seconds (due to real life system delays)
run_config['waiting_factor'] =  15/3600 #constant_factor
run_config['loop'] = 0
run_config['long_job_thres'] = -1
run_config['preempt_cloud_ratio'] = -1

asdf = run_simulator(jobs_100, run_config)
plot_trace_spacetime_and_spillover(asdf, 4)
# Out:
# Jobs progress: 100%|██████████| 115/115 [00:00<00:00, 20555.93it/s]
# Sched Policy    Waiting Policy                   # Cluster Nodes    Total Cloud Cost    Avg. Cloud Cost    Avg. Waiting    Avg. JCT    90th JCT    99th JCT    Cluster Utilization    System Utilization
# --------------  -----------------------------  -----------------  ------------------  -----------------  --------------  ----------  ----------  ----------  ---------------------  --------------------
# fifo            constant-0.004166666666666667                  4             48.2633            19.4645      0.00101587    0.680877     1.95417     2.77306               0.835061               1.11888

# %%
# Constant Wait
run_config['waiting_policy'] = 'constant'
constant_factor =  np.mean([j.runtime for j in jobs_100])/4
run_config['waiting_factor'] =  constant_factor
run_config['loop'] = 0
run_config['long_job_thres'] = -1
run_config['preempt_cloud_ratio'] = -1

asdf = run_simulator(jobs_100, run_config)

total_wait = 0
for i in range(len(asdf['idx'])):
    if asdf['state'][i] == 'LOCAL':
        total_wait += asdf['deadline'][i] - asdf['runtime'][i] - asdf['arrival'][i]
print(total_wait)
plot_trace_spacetime_and_spillover(asdf, 4)
# Out:
# Jobs progress: 100%|██████████| 115/115 [00:00<00:00, 15887.52it/s]
# Sched Policy    Waiting Policy                  # Cluster Nodes    Total Cloud Cost    Avg. Cloud Cost    Avg. Waiting    Avg. JCT    90th JCT    99th JCT    Cluster Utilization    System Utilization
# --------------  ----------------------------  -----------------  ------------------  -----------------  --------------  ----------  ----------  ----------  ---------------------  --------------------
# fifo            constant-0.16630857487922707                  4             37.0611            14.9467       0.0692766    0.749138     2.04611     2.77306               0.870129               1.04997
# 16.797166062801956

# %%
run_config['waiting_policy'] = 'linear_cost'
print( sum([j.runtime * j.num_gpus for j in jobs_100]))
avg_job_size = sum([j.num_gpus for j in jobs_100])/len(jobs_100)
compute_wait_coeff = 0.25/avg_job_size
print(compute_wait_coeff)
run_config['waiting_factor'] =  compute_wait_coeff #0.103#0.27/np.mean([j.num_gpus for j in jobs_100])
print(run_config['waiting_factor'])
run_config['loop'] = 1
asdf1 = run_simulator(jobs_100, run_config)
plot_trace_spacetime_and_spillover(asdf1, 4)

total_wait = 0
for i in range(len(asdf1['idx'])):
    if asdf1['state'][i] == 'LOCAL':
        total_wait += asdf1['deadline'][i] - asdf1['runtime'][i] - asdf1['arrival'][i]
print(total_wait)
# Out:
# 136.3025
# 0.14303482587064678
# 0.14303482587064678
# Jobs progress: 100%|██████████| 115/115 [00:00<00:00, 14942.07it/s]
# Sched Policy    Waiting Policy                     # Cluster Nodes    Total Cloud Cost    Avg. Cloud Cost    Avg. Waiting    Avg. JCT    90th JCT    99th JCT    Cluster Utilization    System Utilization
# --------------  -------------------------------  -----------------  ------------------  -----------------  --------------  ----------  ----------  ----------  ---------------------  --------------------
# fifo            linear_cost-0.14303482587064678                  4             15.4669            6.23779       0.0614418    0.741303     2.08449     2.92956               0.876921              0.975825
# 17.266846323935873

# %%
run_config['waiting_policy'] = 'linear_capacity'
resource_wait_coeff = 0.25 * np.mean([j.runtime for j in jobs_100]) / np.mean([j.num_gpus for j in jobs_100])
print(resource_wait_coeff)
run_config['waiting_factor'] = resource_wait_coeff
run_config['loop'] = 1
run_config['long_job_thres'] = 5/60
run_config['preempt_cloud_ratio'] = 3

asdf1 = run_simulator(jobs_100, run_config)
plot_trace_spacetime_and_spillover(asdf1, 4)

total_wait = 0
for i in range(len(asdf1['idx'])):
    if asdf1['state'][i] == 'LOCAL':
        total_wait += asdf1['deadline'][i] - asdf1['runtime'][i] - asdf1['arrival'][i]
print(total_wait)
# Out:
# 0.10755083514887437
# Jobs progress: 100%|██████████| 89/89 [00:00<00:00, 13712.41it/s]
# Sched Policy    Waiting Policy                         # Cluster Nodes    Total Cloud Cost    Avg. Cloud Cost    Avg. Waiting    Avg. JCT    90th JCT    99th JCT    Cluster Utilization    System Utilization
# --------------  -----------------------------------  -----------------  ------------------  -----------------  --------------  ----------  ----------  ----------  ---------------------  --------------------
# fifo            linear_capacity-0.10755083514887437                  4             5.14944            1.70636       0.0383418    0.777905     2.04611     2.88053               0.707745              0.731729
# 9.303518518518521
